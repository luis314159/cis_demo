# %%
import pandas as pd

# %% [markdown]
# # Read files with utf-8 enconding
#
# Files to be readed:
#
# * app\data_example\62079.csv
# * app\data_example\62080.csv

# %%
path1 = r"F:\aethersoft\cis\cis_demo\app\data_example\62079.csv"
path2 = r"F:\aethersoft\cis\cis_demo\app\data_example\62080.csv"
try:
    df = pd.read_csv(path1, encoding='utf-8')
except Exception as e:
    print(f"Error reading file: {e} in {path1}")

try:    
    df2 = pd.read_csv(path2, encoding='utf-8')
    print_df2 = True
except Exception as e:
    print_df2 = False
    print(f"Error reading file: {e} in {path2}")

df.head()
# Out:
# Error reading file: 'utf-8' codec can't decode byte 0xc1 in position 0: invalid start byte in F:\aethersoft\cis\cis_demo\app\data_example\62079.csv
# Error reading file: 'utf-8' codec can't decode byte 0xc1 in position 0: invalid start byte in F:\aethersoft\cis\cis_demo\app\data_example\62080.csv
#      Job       Item Material  Espesor  Cantidad              OCR    Clase  \
# 0  62079   1248-P10    Steel    6.000         4   62079-1248-P10  Doblado
# 1  62079   1248-P11    Steel    0.250         8   62079-1248-P11    Corte
# 2  62079   1248-P35    Steel    0.750        16   62079-1248-P35    Corte
# 3  62079  1248-P06A    Steel    2.750         1  62079-1248-P06A    Corte
# 4  62079  1248-P06B    Steel    0.375         1  62079-1248-P06B    Corte
#
#    Longitud  Ancho    Alto      Volumen  Área Superficial        Masa
# 0     6.000  76.25  12.000   652.531673        355.447454   83.940725
# 1     6.250   0.25  12.250    19.113786         16.205310    2.458770
# ...

# %%
if print_df2:
    df2.head()
else:
    print(f"Error reading file: {path2}")
# Out:
# Error reading file: F:\aethersoft\cis\cis_demo\app\data_example\62080.csv

# %% [markdown]
# # Read files with latin1 encoding

# %%
try:
    df = pd.read_csv(path1, encoding='latin1')
except Exception as e:
    print(f"Error reading file: {e} in {path1}")

try:    
    df2 = pd.read_csv(path2, encoding='latin1')
except Exception as e:
    print(f"Error reading file: {e} in {path2}")

df.head()
# Out:
#      Job       Item Material  Espesor  Cantidad              OCR    Clase  \
# 0  62079   1248-P10    Steel    6.000         4   62079-1248-P10  Doblado
# 1  62079   1248-P11    Steel    0.250         8   62079-1248-P11    Corte
# 2  62079   1248-P35    Steel    0.750        16   62079-1248-P35    Corte
# 3  62079  1248-P06A    Steel    2.750         1  62079-1248-P06A    Corte
# 4  62079  1248-P06B    Steel    0.375         1  62079-1248-P06B    Corte
#
#    Longitud  Ancho    Alto      Volumen  Área Superficial        Masa
# 0     6.000  76.25  12.000   652.531673        355.447454   83.940725
# 1     6.250   0.25  12.250    19.113786         16.205310    2.458770
# 2     6.500   8.00   0.750    14.906239          5.681813    1.917517
# 3     2.750  78.75  54.875  1679.323061        906.762561  216.025676
# 4     0.375  78.75  45.500  1312.175860        709.270602  168.796394

# %%
df2.head()
# Out:
#      Job       Item Material  Espesor  Cantidad              OCR    Clase  \
# 0  62080   1248-P10    Steel    6.000         4   62080-1248-P10  Doblado
# 1  62080   1248-P11    Steel    0.250         8   62080-1248-P11    Corte
# 2  62080   1248-P35    Steel    0.750        16   62080-1248-P35    Corte
# 3  62080  1248-P06A    Steel    2.750         1  62080-1248-P06A    Corte
# 4  62080  1248-P06B    Steel    0.375         1  62080-1248-P06B    Corte
#
#    Longitud  Ancho    Alto      Volumen  Área Superficial        Masa
# 0     6.000  76.25  12.000   652.531673        355.447454   83.940725
# 1     6.250   0.25  12.250    19.113786         16.205310    2.458770
# 2     6.500   8.00   0.750    14.906239          5.681813    1.917517
# 3     2.750  78.75  54.875  1679.323061        906.762561  216.025676
# 4     0.375  78.75  45.500  1312.175860        709.270602  168.796394
